# %%
import pandas as pd
import numpy as np

input_file = "dataSet_v2.csv"
output_file = "dataSet_v2_fixed.csv"

# %%
#Reemplazar todas los semicolons por comas
with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    for line in infile:
        fixed_line = line.replace(";", ",")
        outfile.write(fixed_line)

# %%
df = pd.read_csv(output_file, sep=",",  on_bad_lines="skip",  low_memory=False)

# %%
# Remover todas las columnas adicionales
df.drop(df.iloc[:, 14:287], inplace=True, axis=1)

# %%
cols_num = [
    'Serial Number',
    'List Year',
    'Assessed Value',
    'Sale Amount'
]

cols_float = [
    'Sales Ratio'
]

# %%
#Cambiar las columnas a tipo numero
for col in [*cols_num, *cols_float]:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    #Borrar todas las filas que tienen null en el id
    df = df.dropna(subset=[col])

# %%
#Cambiar las columnas con datos numericos a ser numero
for col in cols_num:
    df[col] = df[col].astype('int')
    
for col in cols_float:
    df[col] = df[col].astype('float')    

df['Date Recorded'] = pd.to_datetime(df['Date Recorded'])

# %%
df.head(10)
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    2021-09-13  Ansonia        230 WAKELEE AVE
# 1          20002       2020    2020-10-02  Ashford        390 TURNPIKE RD
# 2         200212       2020    2021-03-09     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    2021-04-13     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020    2021-07-02     Avon     70 FAR HILLS DRIVE
# 5         200109       2020    2020-12-09     Avon     57 FAR HILLS DRIVE
# 6        2020180       2020    2021-03-01   Berlin    1539 FARMINGTON AVE
# 7        2020313       2020    2021-07-01   Berlin      216 WATCH HILL RD
# 8         200097       2020    2021-06-04  Bethany            23 AMITY RD
# 9          20139       2020    2020-12-16   Bethel      16 DEEPWOOD DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0          150500       325000       0.4630    Commercial              NaN
# ...

# %%
df['Sell Year'] = df['Date Recorded'].dt.year
df['Sell Year'] = df['Sell Year'].astype('Int64')

# %%
df.head(10)
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    2021-09-13  Ansonia        230 WAKELEE AVE
# 1          20002       2020    2020-10-02  Ashford        390 TURNPIKE RD
# 2         200212       2020    2021-03-09     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    2021-04-13     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020    2021-07-02     Avon     70 FAR HILLS DRIVE
# 5         200109       2020    2020-12-09     Avon     57 FAR HILLS DRIVE
# 6        2020180       2020    2021-03-01   Berlin    1539 FARMINGTON AVE
# 7        2020313       2020    2021-07-01   Berlin      216 WATCH HILL RD
# 8         200097       2020    2021-06-04  Bethany            23 AMITY RD
# 9          20139       2020    2020-12-16   Bethel      16 DEEPWOOD DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0          150500       325000       0.4630    Commercial              NaN
# ...

# %%
#Ingreso anual
#¿Cuál es el ingreso anual de las propiedades vendidas?
result = df.groupby('Sell Year')['Sale Amount'].sum().reset_index()
print(result)
# Out:
#     Sell Year  Sale Amount
# 0        2001   3175872755
# 1        2002  15476278657
# 2        2003  13915000112
# 3        2004   4795804453
# 4        2005     36942348
# 5        2006     32200757
# 6        2007     59070121
# 7        2008     29133190
# 8        2009     23384861
# 9        2010     54236355
# 10       2011     23337070
# 11       2012     45079458
# 12       2013     30219359
# 13       2014     68305886
# 14       2015     67958636
# 15       2016     39698560
# 16       2017     38192196
# 17       2018     73913405
# 18       2019     94778034
# 19       2020   7392777094
# 20       2021  23283260504

# %%
#¿Qué tipo de propiedad tiene mayor facilidad de venta?
conteo_tipo_propiedades = df['Property Type'].value_counts().head(1)
print(conteo_tipo_propiedades)
# Out:
# Property Type
# Residential    51271
# Name: count, dtype: int64

# %%
#¿En cuál ciudad o pueblo se dan mayor cantidad de ventas de propiedades?
conteo_pueblo = df['Town'].value_counts().head(1)
print(conteo_pueblo)
# Out:
# Town
# Stamford    7846
# Name: count, dtype: int64

# %%
# ¿Qué elementos particulares tienen esas ciudades o pueblos?
filtered_df = df[df['Town'] == "Stamford"]
filtered_df.head(10)
# Out:
#      Serial Number  List Year Date Recorded      Town  \
# 200          11407       2001    2002-05-07  Stamford
# 246        2000720       2020    2021-01-05  Stamford
# 247        2000737       2020    2021-01-06  Stamford
# 248        2000857       2020    2021-01-21  Stamford
# 249        2001101       2020    2021-03-04  Stamford
# 250        2001250       2020    2021-03-25  Stamford
# 251        2001286       2020    2021-03-30  Stamford
# 252        2001493       2020    2021-05-03  Stamford
# 253        2001570       2020    2021-05-14  Stamford
# 254        2001590       2020    2021-05-17  Stamford
#
#                            Address  Assessed Value  Sale Amount  Sales Ratio  \
# 200                 27 NORTHILL ST           79730       210000     0.379667
# 246  57 HARBOR DRIVE GARAGE G-105B           19110        27500     0.694900
# 247                LOT 2 EDEN ROAD          208560       238000     0.876300
# ...

# %%
max_val = filtered_df['Sale Amount'].max()
print(max_val)
# Out:
# 154000000

# %%
min_val = filtered_df['Sale Amount'].min()
print(min_val)
# Out:
# 10

# %%
foo_df = filtered_df[filtered_df['Sale Amount'] == 10]

foo_df.head(1)
# Out:
#        Serial Number  List Year Date Recorded      Town         Address  \
# 92334          10717       2001    2002-01-24  Stamford  95 PROSPECT ST
#
#        Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 92334          221060           10      22106.0           NaN
#
#       Residential Type Non Use Code Assessor Remarks OPM remarks Location  \
# 92334              NaN            8              NaN         NaN      NaN
#
#        Sell Year
# 92334       2002

# %%
comercial_df = df[df["Property Type"] == "Commercial"]
residencial_df = df[df["Property Type"] == "Residential"]

# %%
#¿Cuál es el costo promedio de las propiedades residenciales y comerciales?
print("El promedio comercial", comercial_df["Sale Amount"].mean())
print("El promedio residencial", residencial_df["Sale Amount"].mean())
# Out:
# El promedio comercial 1907316.328079393
# El promedio residencial 490270.6977043553

# %%
#. ¿Cuál es tipo de propiedades residenciales que se vende con mayor frecuencia, donde y con que costo promedio?
conteo_tipo_residenciales = df['Residential Type'].value_counts().head(1)
print(conteo_tipo_residenciales)
# Out:
# Residential Type
# Single Family    36379
# Name: count, dtype: int64

# %%
filtrado_tipo_residencial_df = df[df['Residential Type'] == "Single Family"]
# Out:
#    Serial Number  List Year Date Recorded     Town          Address  \
# 1          20002       2020    2020-10-02  Ashford  390 TURNPIKE RD
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 1          253000       430000       0.5883   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location  Sell Year
# 1          NaN              NaN         NaN      NaN       2020

# %%
#donde
print(filtrado_tipo_residencial_df['Town'].value_counts().head(1))
# Out:
# Town
# Stamford    1210
# Name: count, dtype: int64
